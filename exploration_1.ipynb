# %%
import duckdb

con = duckdb.connect()  # in-memory, nothing persisted

# See what's actually in each document type
con.sql("SELECT * FROM read_json('datasets/json/betänkande/*.json', auto_detect=true) LIMIT 3").show()
con.sql("SELECT * FROM read_json('datasets/json/motioner/*.json', auto_detect=true) LIMIT 3").show()
con.sql("SELECT * FROM read_json('datasets/json/propositioner/*.json', auto_detect=true) LIMIT 3").show()
