# %%
import polars as pl
import xmltodict

with open("./datasets/personlista.xml", encoding="utf-8") as f:
    data = xmltodict.parse(f.read())

persons = data["personlista"]["person"]

records = []
for person in persons:
    records.append({
        "intressent_id": person.get("intressent_id", ""),
        "sourceid": person.get("sourceid", ""),
        "tilltalsnamn": person.get("tilltalsnamn", ""),
        "efternamn": person.get("efternamn", ""),
        "sorteringsnamn": person.get("sorteringsnamn", ""),
        "fodd_ar": person.get("fodd_ar", ""),
        "kon": person.get("kon", ""),
        "iort": person.get("iort", ""),
        "parti": person.get("parti", ""),
        "valkrets": person.get("valkrets", ""),
        "status": person.get("status", ""),
        "person_url_xml": person.get("person_url_xml", ""),
        "bild_url_80": person.get("bild_url_80", ""),
        "bild_url_192": person.get("bild_url_192", ""),
        "bild_url_max": person.get("bild_url_max", ""),
    })

df = pl.DataFrame(records)
df
# Out:
# shape: (349, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ intressen ┆ sourceid  ┆ tilltalsn ┆ efternamn ┆ … ┆ person_ur ┆ bild_url_ ┆ bild_url_ ┆ bild_url │
# │ t_id      ┆ ---       ┆ amn       ┆ ---       ┆   ┆ l_xml     ┆ 80        ┆ 192       ┆ _max     │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆           ┆ str       ┆           ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 083808583 ┆ 16c58b85- ┆ Ann-Sofie ┆ Lifvenhag ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 2923      ┆ 7b9a-4f36 ┆           ┆ e         ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -9160-3a4 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ 068…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 060686315 ┆ 7a3c3bff- ┆ Mats      ┆ Berglund  ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 4419      ┆ 401a-45da ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -9f1b-e92 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ d4a…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 013626878 ┆ 43254ea9- ┆ Nima      ┆ Gholam    ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 5826      ┆ ce3e-4cd4 ┆           ┆ Ali Pour  ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -a60c-c62 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ 160…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 049721781 ┆ 4da8bb6b- ┆ Markus    ┆ Selin     ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 6024      ┆ fc06-4f3a ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -ba25-f70 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ dfe…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 087777879 ┆ 90110ece- ┆ Johan     ┆ Büser     ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 3323      ┆ 022e-4e0f ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -bb4e-f51 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ 029…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 087522131 ┆ 11d950d5- ┆ Gunilla   ┆ Carlsson  ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 7013      ┆ e41f-4e94 ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -af86-ae8 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ a19…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 011169735 ┆ b0869471- ┆ Louise    ┆ Eklund    ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 1426      ┆ 2089-4596 ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -9137-ddc ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ 9ef…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 089916986 ┆ 5e7c5792- ┆ Helena    ┆ Gellerman ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 9710      ┆ d4ff-4d8e ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -999f-92e ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ 1a7…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 061291668 ┆ eaf0fa85- ┆ Johan     ┆ Löfstrand ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 4825      ┆ 8858-4e0e ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -97d8-dae ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ e0a…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# │ 061135007 ┆ 703f879e- ┆ Susanne   ┆ Nordström ┆ … ┆ https://d ┆ https://d ┆ https://d ┆ https:// │
# │ 6611      ┆ 0584-42da ┆           ┆           ┆   ┆ ata.riksd ┆ ata.riksd ┆ ata.riksd ┆ data.rik │
# │           ┆ -bc98-b34 ┆           ┆           ┆   ┆ agen.se/p ┆ agen.se/f ┆ agen.se/f ┆ sdagen.s │
# │           ┆ 333…      ┆           ┆           ┆   ┆ ers…      ┆ ila…      ┆ ila…      ┆ e/fila…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
import json
import polars as pl
from pathlib import Path

json_files = sorted(Path("datasets/betänkande").glob("*.json"))
failed = []

for path in json_files:
    try:
        with open(path) as f:
            obj = json.load(f)
        print(obj["dokumentstatus"].keys())
    except json.JSONDecodeError as e:
        failed.append((path.name, str(e)))

if failed:
    print(f"\n{len(failed)} file(s) skipped due to invalid JSON:")
    for name, err in failed:
        print(f"  {name}: {err}")
# Out:
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet', 'dokuppgift', 'dokbilaga'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokbilaga'])
# dict_keys(['dokument', 'dokbilaga'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet'])
# dict_keys(['dokument', 'dokaktivitet'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# ...
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet'])
# dict_keys(['dokument', 'dokaktivitet'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet', 'dokreferens'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokaktivitet', 'dokuppgift', 'dokreferens'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
# dict_keys(['dokument', 'dokutskottsforslag', 'dokmotforslag', 'dokaktivitet', 'dokuppgift', 'dokbilaga', 'dokreferens', 'debatt', 'webbmedia'])
#
# 9 file(s) skipped due to invalid JSON:
#   ha01cu4.json: Expecting ',' delimiter: line 1 column 79088 (char 79087)
#   hc01uu15.json: Expecting ',' delimiter: line 1 column 287706 (char 287705)
#   hd01f”u14.json: Expecting ',' delimiter: line 1 column 138770 (char 138769)
#   hd01sfu30.json: Expecting ',' delimiter: line 1 column 196692 (char 196691)
#   hd01sfu31.json: Expecting ',' delimiter: line 1 column 157707 (char 157706)
#   hd01sfu32.json: Expecting ',' delimiter: line 1 column 141701 (char 141700)
#   hd01uf”u3.json: Expecting ',' delimiter: line 1 column 57705 (char 57704)
#   hd01uu6.json: Expecting ',' delimiter: line 1 column 198523 (char 198522)
#   hd01uu9.json: Expecting ',' delimiter: line 1 column 158408 (char 158407)
